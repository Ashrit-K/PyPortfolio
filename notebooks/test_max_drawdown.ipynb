# %%
cd ..
# Out:
# /Users/ashrit/Desktop/Learning

# %%
import pandas as pd
import pandas_datareader.data as pdr
import yfinance as yf
import datetime as dt
from PyPortfolio import *
yf.pdr_override()
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
start = dt.datetime(2000,1,2)
end = dt.datetime.today()
SPY_prices_daily = pdr.get_data_yahoo('SPY', start=start, end=end)
SPY_prices_monthly = SPY_prices_daily['Adj Close'].resample('M').last()
SPY_returns_monthly = SPY_prices_monthly.pct_change().dropna()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
max_drawdown_internal = max_drawdown(SPY_returns_monthly)
max_drawdown_internal['drawdown'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>
